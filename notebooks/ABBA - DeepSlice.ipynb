# %% [markdown]
# # [Aligning Big Brains and Atlases](https://biop.github.io/ijp-imagetoatlas/) in Python
#
# This notebook demos the use of ABBA with python. In particular it integrates [DeepSlice](https://github.com/PolarBean/DeepSlice) with ABBA.
#
# Technically speaking, this notebook relies on [JPype](https://github.com/jpype-project/jpype) and [PyImageJ](https://github.com/imagej/pyimagej) to make the bridge between Python and Java. Surprisingly, there's no almost no functionality loss...
#
# Note that ABBA works for aligning serial sections. If you want to register a nice 3D dataset, you'd rather have a look at [brainreg](https://github.com/brainglobe/brainreg).
#
#
# ## What happens in this notebook ?
#
# We start ABBA, download a few serial sections example, register them with DeepSlice. Finally non-linear registration.

# %%
# Starting PyImageJ, some of these dependencies may be autodiscovered via transitive dependencies, not sure

imagej_core_dep = 'net.imagej:imagej:2.3.0'
imagej_legacy_dep = 'net.imagej:imagej-legacy:0.38.1'
abba_dep = 'ch.epfl.biop:ImageToAtlasRegister:0.2.11'

deps_pack = [imagej_core_dep, imagej_legacy_dep, abba_dep]

# %%
# Starts ImageJ, show UI
import imagej
ij = imagej.init(deps_pack, mode='interactive')
ij.ui().showUI()

# %%
# Starts ABBA
from scyjava import jimport
import jpype
import jpype.imports
from jpype.types import *
from jpype import JImplements, JOverride
# .. but before : logger, please shut up
DebugTools = jimport('loci.common.DebugTools')
DebugTools.enableLogging('INFO')

# Ok, let's start ABBA and its BDV view (it's also possible to start it without any GUI, 
# or even to build another GUI with a Napari view, why not ?)

ABBABdvStartCommand = jimport('ch.epfl.biop.atlas.aligner.gui.bdv.ABBABdvStartCommand') # Command import
ij.command().run(ABBABdvStartCommand, True, 'slicing_mode', 'coronal') # Starts it with the converted brainglobe atlas in the coronal orientation
# Out:
# <java object 'java.util.concurrent.FutureTask'>
# [java.lang.Enum.toString] [WARNING] Ignoring unsupported output: ba [ch.epfl.biop.atlas.mouse.allen.ccfv3.command.AllenBrainAdultMouseAtlasCCF2017Command]
# [java.lang.Enum.toString] [WARNING] Ignoring unsupported output: atlas [ch.epfl.biop.atlas.mouse.allen.ccfv3.command.AllenBrainAdultMouseAtlasCCF2017Command]
# [java.lang.Enum.toString] Creating MultiSlicePositioner instance
# [java.lang.Enum.toString] MultiSlicePositioner instance created
# [java.lang.Enum.toString] [WARNING] Ignoring unsupported output: mp [ch.epfl.biop.atlas.aligner.MultiSlicePositioner]
# [java.lang.Enum.toString] Registration plugin RegistrationElastixAffineCommand discovered
# [java.lang.Enum.toString] Registration plugin RegistrationElastixAffineRemoteCommand discovered
# [java.lang.Enum.toString] Registration plugin RegistrationBigWarpCommand discovered
# [java.lang.Enum.toString] Registration plugin RegistrationElastixSplineCommand discovered
# [java.lang.Enum.toString] Registration plugin RegistrationElastixSplineRemoteCommand discovered
# [java.lang.Enum.toString] [WARNING] Ignoring unsupported output: view [ch.epfl.biop.atlas.aligner.gui.bdv.BdvMultislicePositionerView]
# [java.lang.Enum.toString] IRunTimeClassAdapters :
# [java.lang.Enum.toString] 	 interface net.imglib2.realtransform.RealTransform
# [java.lang.Enum.toString] 	 	 class bdv.util.BoundedRealTransform
# [java.lang.Enum.toString] 	 	 class bdv.util.Elliptical3DTransform
# [java.lang.Enum.toString] 	 	 class net.imglib2.realtransform.AffineTransform3D
# [java.lang.Enum.toString] 	 	 class net.imglib2.realtransform.InvertibleRealTransformSequence
# [java.lang.Enum.toString] 	 	 class net.imglib2.realtransform.RealTransformSequence
# [java.lang.Enum.toString] 	 	 class net.imglib2.realtransform.ThinplateSplineTransform
# [java.lang.Enum.toString] 	 	 class net.imglib2.realtransform.Wrapped2DTransformAs3D
# [java.lang.Enum.toString] 	 	 class net.imglib2.realtransform.inverse.WrappedIterativeInvertibleRealTransform
# [java.lang.Enum.toString] 	 interface sc.fiji.bdvpg.bdv.supplier.IBdvSupplier
# [java.lang.Enum.toString] 	 	 class sc.fiji.bdvpg.bdv.supplier.DefaultBdvSupplier
# [java.lang.Enum.toString] 	 	 class sc.fiji.bdvpg.bdv.supplier.alpha.AlphaBdvSupplier
# [java.lang.Enum.toString] 	 	 class sc.fiji.bdvpg.bdv.supplier.biop.BiopBdvSupplier
# [java.lang.Enum.toString] 	 interface bdv.viewer.render.AccumulateProjectorFactory
# [java.lang.Enum.toString] 	 	 class bdv.util.projector.alpha.LayerAlphaProjectorFactory
# [java.lang.Enum.toString] 	 	 class sc.fiji.bdvpg.bdv.projector.DefaultAccumulatorFactory
# [java.lang.Enum.toString] IClassAdapters :
# [java.lang.Enum.toString] 	 class net.imglib2.realtransform.AffineTransform3D
# [java.lang.Enum.toString] 	 class net.imglib2.realtransform.InvertibleRealTransformSequence
# [java.lang.Enum.toString] 	 class net.imglib2.realtransform.RealTransformSequence
# [java.lang.Enum.toString] 	 class net.imglib2.realtransform.ThinplateSplineTransform
# [java.lang.Enum.toString] 	 class net.imglib2.realtransform.Wrapped2DTransformAs3D
# [java.lang.Enum.toString] 	 class net.imglib2.realtransform.inverse.WrappedIterativeInvertibleRealTransform
# [java.lang.Enum.toString] IRunTimeClassAdapters :
# [java.lang.Enum.toString] 	 interface net.imglib2.realtransform.RealTransform
# [java.lang.Enum.toString] 	 	 class bdv.util.BoundedRealTransform
# [java.lang.Enum.toString] 	 	 class bdv.util.Elliptical3DTransform
# [java.lang.Enum.toString] 	 	 class net.imglib2.realtransform.AffineTransform3D
# [java.lang.Enum.toString] 	 	 class net.imglib2.realtransform.InvertibleRealTransformSequence
# [java.lang.Enum.toString] 	 	 class net.imglib2.realtransform.RealTransformSequence
# [java.lang.Enum.toString] 	 	 class net.imglib2.realtransform.ThinplateSplineTransform
# [java.lang.Enum.toString] 	 	 class net.imglib2.realtransform.Wrapped2DTransformAs3D
# [java.lang.Enum.toString] 	 	 class net.imglib2.realtransform.inverse.WrappedIterativeInvertibleRealTransform
# [java.lang.Enum.toString] 	 interface sc.fiji.bdvpg.bdv.supplier.IBdvSupplier
# [java.lang.Enum.toString] 	 	 class sc.fiji.bdvpg.bdv.supplier.DefaultBdvSupplier
# [java.lang.Enum.toString] 	 	 class sc.fiji.bdvpg.bdv.supplier.alpha.AlphaBdvSupplier
# [java.lang.Enum.toString] 	 	 class sc.fiji.bdvpg.bdv.supplier.biop.BiopBdvSupplier
# [java.lang.Enum.toString] 	 interface bdv.viewer.render.AccumulateProjectorFactory
# [java.lang.Enum.toString] 	 	 class bdv.util.projector.alpha.LayerAlphaProjectorFactory
# [java.lang.Enum.toString] 	 	 class sc.fiji.bdvpg.bdv.projector.DefaultAccumulatorFactory
# [java.lang.Enum.toString] IClassAdapters :
# [java.lang.Enum.toString] 	 class net.imglib2.realtransform.AffineTransform3D
# [java.lang.Enum.toString] 	 class net.imglib2.realtransform.InvertibleRealTransformSequence
# [java.lang.Enum.toString] 	 class net.imglib2.realtransform.RealTransformSequence
# [java.lang.Enum.toString] 	 class net.imglib2.realtransform.ThinplateSplineTransform
# [java.lang.Enum.toString] 	 class net.imglib2.realtransform.Wrapped2DTransformAs3D
# [java.lang.Enum.toString] 	 class net.imglib2.realtransform.inverse.WrappedIterativeInvertibleRealTransform
# [java.lang.Enum.toString] ch.epfl.biop.java.utilities.roi.ConvertibleRois[java.lang.Enum.toString]
# [java.lang.Enum.toString]  z position changed[java.lang.Enum.toString]
# [java.lang.Enum.toString] Creating slice S00.tif-ch0...
# [java.lang.Enum.toString] S00.tif-ch0 created[java.lang.Enum.toString]
# [java.lang.Enum.toString] Initializing S00.tif-ch0[java.lang.Enum.toString]
# [java.lang.Enum.toString] S00.tif-ch0 z position changed[java.lang.Enum.toString]
# [java.lang.Enum.toString] S00.tif-ch0 deselected[java.lang.Enum.toString]
# [java.lang.Enum.toString] Slice S00.tif-ch0 created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] ch.epfl.biop.java.utilities.roi.ConvertibleRois[java.lang.Enum.toString]
# [java.lang.Enum.toString]  z position changed[java.lang.Enum.toString]
# [java.lang.Enum.toString] Creating slice S10.tif-ch0...
# [java.lang.Enum.toString] S10.tif-ch0 created[java.lang.Enum.toString]
# [java.lang.Enum.toString] Initializing S10.tif-ch0[java.lang.Enum.toString]
# [java.lang.Enum.toString] S10.tif-ch0 z position changed[java.lang.Enum.toString]
# [java.lang.Enum.toString] S10.tif-ch0 deselected[java.lang.Enum.toString]
# [java.lang.Enum.toString] Slice S10.tif-ch0 created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] ch.epfl.biop.java.utilities.roi.ConvertibleRois[java.lang.Enum.toString]
# [java.lang.Enum.toString]  z position changed[java.lang.Enum.toString]
# [java.lang.Enum.toString] Creating slice S20.tif-ch0...
# [java.lang.Enum.toString] S20.tif-ch0 created[java.lang.Enum.toString]
# [java.lang.Enum.toString] Initializing S20.tif-ch0[java.lang.Enum.toString]
# [java.lang.Enum.toString] S20.tif-ch0 z position changed[java.lang.Enum.toString]
# [java.lang.Enum.toString] S20.tif-ch0 deselected[java.lang.Enum.toString]
# [java.lang.Enum.toString] Slice S20.tif-ch0 created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] ch.epfl.biop.java.utilities.roi.ConvertibleRois[java.lang.Enum.toString]
# [java.lang.Enum.toString]  z position changed[java.lang.Enum.toString]
# [java.lang.Enum.toString] Creating slice S30.tif-ch0...
# [java.lang.Enum.toString] S30.tif-ch0 created[java.lang.Enum.toString]
# [java.lang.Enum.toString] Initializing S30.tif-ch0[java.lang.Enum.toString]
# [java.lang.Enum.toString] S30.tif-ch0 z position changed[java.lang.Enum.toString]
# [java.lang.Enum.toString] S30.tif-ch0 deselected[java.lang.Enum.toString]
# [java.lang.Enum.toString] Slice S30.tif-ch0 created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] ch.epfl.biop.java.utilities.roi.ConvertibleRois[java.lang.Enum.toString]
# [java.lang.Enum.toString]  z position changed[java.lang.Enum.toString]
# [java.lang.Enum.toString] Creating slice S40.tif-ch0...
# [java.lang.Enum.toString] S40.tif-ch0 created[java.lang.Enum.toString]
# [java.lang.Enum.toString] Initializing S40.tif-ch0[java.lang.Enum.toString]
# [java.lang.Enum.toString] S40.tif-ch0 z position changed[java.lang.Enum.toString]
# [java.lang.Enum.toString] S40.tif-ch0 deselected[java.lang.Enum.toString]
# [java.lang.Enum.toString] Slice S40.tif-ch0 created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] ch.epfl.biop.java.utilities.roi.ConvertibleRois[java.lang.Enum.toString]
# [java.lang.Enum.toString]  z position changed[java.lang.Enum.toString]
# [java.lang.Enum.toString] Creating slice S50.tif-ch0...
# [java.lang.Enum.toString] S50.tif-ch0 created[java.lang.Enum.toString]
# [java.lang.Enum.toString] Initializing S50.tif-ch0[java.lang.Enum.toString]
# [java.lang.Enum.toString] S50.tif-ch0 z position changed[java.lang.Enum.toString]
# [java.lang.Enum.toString] S50.tif-ch0 deselected[java.lang.Enum.toString]
# [java.lang.Enum.toString] Slice S50.tif-ch0 created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] ch.epfl.biop.java.utilities.roi.ConvertibleRois[java.lang.Enum.toString]
# [java.lang.Enum.toString]  z position changed[java.lang.Enum.toString]
# [java.lang.Enum.toString] Creating slice S60.tif-ch0...
# [java.lang.Enum.toString] S60.tif-ch0 created[java.lang.Enum.toString]
# [java.lang.Enum.toString] Initializing S60.tif-ch0[java.lang.Enum.toString]
# [java.lang.Enum.toString] S60.tif-ch0 z position changed[java.lang.Enum.toString]
# [java.lang.Enum.toString] S60.tif-ch0 deselected[java.lang.Enum.toString]
# [java.lang.Enum.toString] Slice S60.tif-ch0 created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] ch.epfl.biop.java.utilities.roi.ConvertibleRois[java.lang.Enum.toString]
# [java.lang.Enum.toString]  z position changed[java.lang.Enum.toString]
# [java.lang.Enum.toString] Creating slice S70.tif-ch0...
# [java.lang.Enum.toString] S70.tif-ch0 created[java.lang.Enum.toString]
# [java.lang.Enum.toString] Initializing S70.tif-ch0[java.lang.Enum.toString]
# [java.lang.Enum.toString] S70.tif-ch0 z position changed[java.lang.Enum.toString]
# [java.lang.Enum.toString] S70.tif-ch0 deselected[java.lang.Enum.toString]
# [java.lang.Enum.toString] Slice S70.tif-ch0 created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] ch.epfl.biop.java.utilities.roi.ConvertibleRois[java.lang.Enum.toString]
# [java.lang.Enum.toString]  z position changed[java.lang.Enum.toString]
# [java.lang.Enum.toString] Creating slice S80.tif-ch0...
# [java.lang.Enum.toString] S80.tif-ch0 created[java.lang.Enum.toString]
# [java.lang.Enum.toString] Initializing S80.tif-ch0[java.lang.Enum.toString]
# [java.lang.Enum.toString] S80.tif-ch0 z position changed[java.lang.Enum.toString]
# [java.lang.Enum.toString] S80.tif-ch0 deselected[java.lang.Enum.toString]
# [java.lang.Enum.toString] Slice S80.tif-ch0 created!
# [java.lang.Enum.toString] Multipositioner : Slice added
# [java.lang.Enum.toString] S00.tif-ch0 selected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S10.tif-ch0 selected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S20.tif-ch0 selected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S30.tif-ch0 selected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S40.tif-ch0 selected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S50.tif-ch0 selected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S60.tif-ch0 selected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S70.tif-ch0 selected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S80.tif-ch0 selected[java.lang.Enum.toString]
# [java.lang.Enum.toString] Exception in thread "AWT-EventQueue-0" [java.lang.Enum.toString] java.lang.NoClassDefFoundError: javax/xml/bind/ValidationEventHandler[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/java.lang.Class.getDeclaredConstructors0(Native Method)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/java.lang.Class.privateGetDeclaredConstructors(Class.java:3137)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/java.lang.Class.getConstructor0(Class.java:3342)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/java.lang.Class.newInstance(Class.java:556)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at org.scijava.plugin.PluginInfo.createInstance(PluginInfo.java:304)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at org.scijava.command.CommandInfo.createInstance(CommandInfo.java:248)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at org.scijava.command.CommandModule.instantiateCommand(CommandModule.java:248)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at org.scijava.command.CommandModule.<init>(CommandModule.java:98)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at org.scijava.command.CommandInfo.createModule(CommandInfo.java:326)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at org.scijava.module.DefaultModuleService.createModule(DefaultModuleService.java:167)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at org.scijava.module.DefaultModuleService.run(DefaultModuleService.java:206)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at org.scijava.module.DefaultModuleService.run(DefaultModuleService.java:197)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at org.scijava.module.DefaultModuleService.run(DefaultModuleService.java:182)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at org.scijava.command.DefaultCommandService.run(DefaultCommandService.java:183)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at org.scijava.command.DefaultCommandService.run(DefaultCommandService.java:168)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at sc.fiji.bdvpg.scijava.BdvScijavaHelper.lambda$addCommandToBdvHandleMenu$0(BdvScijavaHelper.java:69)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at sc.fiji.bdvpg.scijava.BdvScijavaHelper.lambda$addActionToBdvHandleMenu$1(BdvScijavaHelper.java:85)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/javax.swing.AbstractButton.fireActionPerformed(AbstractButton.java:1967)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/javax.swing.AbstractButton$Handler.actionPerformed(AbstractButton.java:2308)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/javax.swing.DefaultButtonModel.fireActionPerformed(DefaultButtonModel.java:405)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/javax.swing.DefaultButtonModel.setPressed(DefaultButtonModel.java:262)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/javax.swing.AbstractButton.doClick(AbstractButton.java:369)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/javax.swing.plaf.basic.BasicMenuItemUI.doClick(BasicMenuItemUI.java:1020)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/javax.swing.plaf.basic.BasicMenuItemUI$Handler.mouseReleased(BasicMenuItemUI.java:1064)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.Component.processMouseEvent(Component.java:6635)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/javax.swing.JComponent.processMouseEvent(JComponent.java:3342)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.Component.processEvent(Component.java:6400)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.Container.processEvent(Container.java:2263)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.Component.dispatchEventImpl(Component.java:5011)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.Container.dispatchEventImpl(Container.java:2321)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.Component.dispatchEvent(Component.java:4843)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.LightweightDispatcher.retargetMouseEvent(Container.java:4918)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.LightweightDispatcher.processMouseEvent(Container.java:4547)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.LightweightDispatcher.dispatchEvent(Container.java:4488)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.Container.dispatchEventImpl(Container.java:2307)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.Window.dispatchEventImpl(Window.java:2772)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.Component.dispatchEvent(Component.java:4843)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventQueue.dispatchEventImpl(EventQueue.java:772)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventQueue$4.run(EventQueue.java:721)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventQueue$4.run(EventQueue.java:715)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/java.security.AccessController.doPrivileged(Native Method)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:85)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:95)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventQueue$5.run(EventQueue.java:745)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventQueue$5.run(EventQueue.java:743)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/java.security.AccessController.doPrivileged(Native Method)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:85)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventQueue.dispatchEvent(EventQueue.java:742)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventDispatchThread.pumpOneEventForFilters(EventDispatchThread.java:203)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventDispatchThread.pumpEventsForFilter(EventDispatchThread.java:124)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventDispatchThread.pumpEventsForHierarchy(EventDispatchThread.java:113)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:109)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:101)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventDispatchThread.run(EventDispatchThread.java:90)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Caused by: java.lang.ClassNotFoundException: javax.xml.bind.ValidationEventHandler[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:581)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:178)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:522)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	... 54 more[java.lang.Enum.toString]
# [java.lang.Enum.toString] Exception in thread "AWT-EventQueue-0" [java.lang.Enum.toString] java.lang.NoClassDefFoundError: javax/xml/bind/ValidationEventHandler[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/java.lang.Class.getDeclaredConstructors0(Native Method)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/java.lang.Class.privateGetDeclaredConstructors(Class.java:3137)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/java.lang.Class.getConstructor0(Class.java:3342)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/java.lang.Class.newInstance(Class.java:556)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at org.scijava.plugin.PluginInfo.createInstance(PluginInfo.java:304)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at org.scijava.command.CommandInfo.createInstance(CommandInfo.java:248)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at org.scijava.command.CommandModule.instantiateCommand(CommandModule.java:248)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at org.scijava.command.CommandModule.<init>(CommandModule.java:98)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at org.scijava.command.CommandInfo.createModule(CommandInfo.java:326)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at org.scijava.module.DefaultModuleService.createModule(DefaultModuleService.java:167)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at org.scijava.module.DefaultModuleService.run(DefaultModuleService.java:206)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at org.scijava.module.DefaultModuleService.run(DefaultModuleService.java:197)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at org.scijava.module.DefaultModuleService.run(DefaultModuleService.java:182)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at org.scijava.command.DefaultCommandService.run(DefaultCommandService.java:183)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at org.scijava.command.DefaultCommandService.run(DefaultCommandService.java:168)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at sc.fiji.bdvpg.scijava.BdvScijavaHelper.lambda$addCommandToBdvHandleMenu$0(BdvScijavaHelper.java:69)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at sc.fiji.bdvpg.scijava.BdvScijavaHelper.lambda$addActionToBdvHandleMenu$1(BdvScijavaHelper.java:85)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/javax.swing.AbstractButton.fireActionPerformed(AbstractButton.java:1967)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/javax.swing.AbstractButton$Handler.actionPerformed(AbstractButton.java:2308)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/javax.swing.DefaultButtonModel.fireActionPerformed(DefaultButtonModel.java:405)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/javax.swing.DefaultButtonModel.setPressed(DefaultButtonModel.java:262)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/javax.swing.AbstractButton.doClick(AbstractButton.java:369)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/javax.swing.plaf.basic.BasicMenuItemUI.doClick(BasicMenuItemUI.java:1020)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/javax.swing.plaf.basic.BasicMenuItemUI$Handler.mouseReleased(BasicMenuItemUI.java:1064)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.Component.processMouseEvent(Component.java:6635)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/javax.swing.JComponent.processMouseEvent(JComponent.java:3342)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.Component.processEvent(Component.java:6400)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.Container.processEvent(Container.java:2263)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.Component.dispatchEventImpl(Component.java:5011)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.Container.dispatchEventImpl(Container.java:2321)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.Component.dispatchEvent(Component.java:4843)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.LightweightDispatcher.retargetMouseEvent(Container.java:4918)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.LightweightDispatcher.processMouseEvent(Container.java:4547)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.LightweightDispatcher.dispatchEvent(Container.java:4488)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.Container.dispatchEventImpl(Container.java:2307)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.Window.dispatchEventImpl(Window.java:2772)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.Component.dispatchEvent(Component.java:4843)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventQueue.dispatchEventImpl(EventQueue.java:772)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventQueue$4.run(EventQueue.java:721)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventQueue$4.run(EventQueue.java:715)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/java.security.AccessController.doPrivileged(Native Method)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:85)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:95)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventQueue$5.run(EventQueue.java:745)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventQueue$5.run(EventQueue.java:743)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/java.security.AccessController.doPrivileged(Native Method)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:85)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventQueue.dispatchEvent(EventQueue.java:742)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventDispatchThread.pumpOneEventForFilters(EventDispatchThread.java:203)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventDispatchThread.pumpEventsForFilter(EventDispatchThread.java:124)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventDispatchThread.pumpEventsForHierarchy(EventDispatchThread.java:113)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:109)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:101)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventDispatchThread.run(EventDispatchThread.java:90)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Caused by: java.lang.ClassNotFoundException: javax.xml.bind.ValidationEventHandler[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:581)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:178)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:522)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	... 54 more[java.lang.Enum.toString]
# [java.lang.Enum.toString] S00.tif-ch0 deselected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S10.tif-ch0 deselected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S20.tif-ch0 deselected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S30.tif-ch0 deselected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S40.tif-ch0 deselected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S50.tif-ch0 deselected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S60.tif-ch0 deselected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S70.tif-ch0 deselected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S80.tif-ch0 deselected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S00.tif-ch0 selected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S10.tif-ch0 selected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S20.tif-ch0 selected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S30.tif-ch0 selected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S40.tif-ch0 selected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S50.tif-ch0 selected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S60.tif-ch0 selected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S70.tif-ch0 selected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S80.tif-ch0 selected[java.lang.Enum.toString]
# [java.lang.Enum.toString] Exception in thread "AWT-EventQueue-0" [java.lang.Enum.toString] java.lang.NoClassDefFoundError: javax/xml/bind/ValidationEventHandler[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/java.lang.Class.getDeclaredConstructors0(Native Method)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/java.lang.Class.privateGetDeclaredConstructors(Class.java:3137)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/java.lang.Class.getConstructor0(Class.java:3342)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/java.lang.Class.newInstance(Class.java:556)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at org.scijava.plugin.PluginInfo.createInstance(PluginInfo.java:304)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at org.scijava.command.CommandInfo.createInstance(CommandInfo.java:248)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at org.scijava.command.CommandModule.instantiateCommand(CommandModule.java:248)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at org.scijava.command.CommandModule.<init>(CommandModule.java:98)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at org.scijava.command.CommandInfo.createModule(CommandInfo.java:326)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at org.scijava.module.DefaultModuleService.createModule(DefaultModuleService.java:167)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at org.scijava.module.DefaultModuleService.run(DefaultModuleService.java:206)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at org.scijava.module.DefaultModuleService.run(DefaultModuleService.java:197)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at org.scijava.module.DefaultModuleService.run(DefaultModuleService.java:182)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at org.scijava.command.DefaultCommandService.run(DefaultCommandService.java:183)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at org.scijava.command.DefaultCommandService.run(DefaultCommandService.java:168)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at sc.fiji.bdvpg.scijava.BdvScijavaHelper.lambda$addCommandToBdvHandleMenu$0(BdvScijavaHelper.java:69)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at sc.fiji.bdvpg.scijava.BdvScijavaHelper.lambda$addActionToBdvHandleMenu$1(BdvScijavaHelper.java:85)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/javax.swing.AbstractButton.fireActionPerformed(AbstractButton.java:1967)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/javax.swing.AbstractButton$Handler.actionPerformed(AbstractButton.java:2308)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/javax.swing.DefaultButtonModel.fireActionPerformed(DefaultButtonModel.java:405)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/javax.swing.DefaultButtonModel.setPressed(DefaultButtonModel.java:262)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/javax.swing.AbstractButton.doClick(AbstractButton.java:369)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/javax.swing.plaf.basic.BasicMenuItemUI.doClick(BasicMenuItemUI.java:1020)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/javax.swing.plaf.basic.BasicMenuItemUI$Handler.mouseReleased(BasicMenuItemUI.java:1064)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.Component.processMouseEvent(Component.java:6635)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/javax.swing.JComponent.processMouseEvent(JComponent.java:3342)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.Component.processEvent(Component.java:6400)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.Container.processEvent(Container.java:2263)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.Component.dispatchEventImpl(Component.java:5011)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.Container.dispatchEventImpl(Container.java:2321)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.Component.dispatchEvent(Component.java:4843)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.LightweightDispatcher.retargetMouseEvent(Container.java:4918)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.LightweightDispatcher.processMouseEvent(Container.java:4547)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.LightweightDispatcher.dispatchEvent(Container.java:4488)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.Container.dispatchEventImpl(Container.java:2307)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.Window.dispatchEventImpl(Window.java:2772)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.Component.dispatchEvent(Component.java:4843)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventQueue.dispatchEventImpl(EventQueue.java:772)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventQueue$4.run(EventQueue.java:721)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventQueue$4.run(EventQueue.java:715)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/java.security.AccessController.doPrivileged(Native Method)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:85)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:95)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventQueue$5.run(EventQueue.java:745)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventQueue$5.run(EventQueue.java:743)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/java.security.AccessController.doPrivileged(Native Method)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:85)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventQueue.dispatchEvent(EventQueue.java:742)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventDispatchThread.pumpOneEventForFilters(EventDispatchThread.java:203)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventDispatchThread.pumpEventsForFilter(EventDispatchThread.java:124)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventDispatchThread.pumpEventsForHierarchy(EventDispatchThread.java:113)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:109)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:101)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.desktop/java.awt.EventDispatchThread.run(EventDispatchThread.java:90)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Caused by: java.lang.ClassNotFoundException: javax.xml.bind.ValidationEventHandler[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:581)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:178)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:522)[java.lang.Enum.toString]
# [java.lang.Enum.toString] 	... 54 more[java.lang.Enum.toString]
# [java.lang.Enum.toString] S00.tif-ch0 deselected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S10.tif-ch0 deselected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S20.tif-ch0 deselected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S30.tif-ch0 deselected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S40.tif-ch0 deselected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S50.tif-ch0 deselected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S60.tif-ch0 deselected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S70.tif-ch0 deselected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S80.tif-ch0 deselected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S00.tif-ch0 selected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S10.tif-ch0 selected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S20.tif-ch0 selected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S30.tif-ch0 selected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S40.tif-ch0 selected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S50.tif-ch0 selected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S60.tif-ch0 selected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S70.tif-ch0 selected[java.lang.Enum.toString]
# [java.lang.Enum.toString] S80.tif-ch0 selected[java.lang.Enum.toString]
# [java.lang.Enum.toString] Closing multipositioner bdv window, releasing some resources.
# [java.lang.Enum.toString] Closing multipositioner bdv window, releasing some resources.

# %% [markdown]
# ## Download serial sections examples
#
# Download sections from the zenodo repository: https://zenodo.org/record/6592478#.YpSyc1RByUk (around 1Mb per section)
#
# Files are put in the current repository, under the `images` folder. If files have already been downloaded, the download will be skipped.

# %%
import os
from bg_atlasapi import utils
from pathlib import Path
cwd = os.getcwd() # gets current path

utils.check_internet_connection()
base_zenodo_url = 'https://zenodo.org/record/4715656/'

basePath = cwd+'/images/'

def downloadIfNecessary(section_name):
    outputPath = Path(basePath+section_name)
    if not outputPath.exists():
        url = 'https://zenodo.org/record/6592478/files/'+section_name+'?download=1'
        utils.retrieve_over_http(url, outputPath)
    
downloadIfNecessary('S00.tif') 
downloadIfNecessary('S10.tif') 
downloadIfNecessary('S20.tif') 
downloadIfNecessary('S30.tif') 
downloadIfNecessary('S40.tif') 
downloadIfNecessary('S50.tif') 
downloadIfNecessary('S60.tif') 
downloadIfNecessary('S70.tif') 
downloadIfNecessary('S80.tif')

# %%
# Let's get the multipositioner object 
MultiSlicePositioner = jimport('ch.epfl.biop.atlas.aligner.MultiSlicePositioner')

# There's only one multipositioner instance in the object service
# https://javadoc.scijava.org/SciJava/org/scijava/object/ObjectService.html
mp = ij.object().getObjects(MultiSlicePositioner).get(0)

# %%
# Let's import the files using Bio-Formats.
# The list of all commands is accessible here:
# https://github.com/BIOP/ijp-imagetoatlas/tree/master/src/main/java/ch/epfl/biop/atlas/aligner/command

ImportImageCommand = jimport('ch.epfl.biop.atlas.aligner.command.ImportImageCommand')

# Here we want to import images: check
# https://github.com/BIOP/ijp-imagetoatlas/blob/master/src/main/java/ch/epfl/biop/atlas/aligner/command/ImportImageCommand.java

File = jimport('java.io.File')

file_s00 = File(basePath+'S00.tif')
file_s10 = File(basePath+'S10.tif')
file_s20 = File(basePath+'S20.tif')
file_s30 = File(basePath+'S30.tif')
file_s40 = File(basePath+'S40.tif')
file_s50 = File(basePath+'S50.tif')
file_s60 = File(basePath+'S60.tif')
file_s70 = File(basePath+'S70.tif')
file_s80 = File(basePath+'S80.tif')

FileArray = JArray(File)
files = FileArray(9)

files[0] = file_s00
files[1] = file_s10
files[2] = file_s20
files[3] = file_s30
files[4] = file_s40
files[5] = file_s50
files[6] = file_s60
files[7] = file_s70
files[8] = file_s80

# Any missing input parameter will lead to a popup window asking the missing argument to the user
ij.command().run(ImportImageCommand, True,\
                 "datasetname", JString('dataset'),\
                 "files", files,\
                 "mp", mp,\
                 "split_rgb_channels", False,\
                 "slice_axis_initial", 5.0,\
                 "increment_between_slices", 0.04\
                )

# %%
mp.selectSlice(mp.getSlices()) # select all slices

# %%
mp.getReslicedAtlas().setRotateY(0.05) # Small correction in Y slicing

# %%
mp.deselectSlice(mp.getSlices()) # deselect all

# %%
mp.selectSlice(mp.getSlices().get(2)) # select the last slice

# %%
# Gets the bigdataviewer view. First let's get the class
BdvMultislicePositionerView = jimport('ch.epfl.biop.atlas.aligner.gui.bdv.BdvMultislicePositionerView')

# %%
# view = ij.object().getObjects(BdvMultislicePositionerView).get(0) # Only one BigDataViewer view
# TODO : use fix in newer version to access the view through the object service

# %%
# The slices are always sorted from small z to high z. To keep track of who's who, reference them before moving them
slice00 = mp.getSlices().get(0) 
slice10 = mp.getSlices().get(1)
slice20 = mp.getSlices().get(2)
slice30 = mp.getSlices().get(3) 
slice40 = mp.getSlices().get(4)
slice50 = mp.getSlices().get(5)
slice60 = mp.getSlices().get(6) 
slice70 = mp.getSlices().get(7)
slice80 = mp.getSlices().get(8)

# %%
mp.moveSlice(slice50,9.5)

# %%
mp.moveSlice(slice40,8.2)

# %%
mp.moveSlice(slice30,7.5)

# %%
# Simple actions are accessible through mp.whatever, but most actions are executed on selected slices
# Almost all actions are executed asynchronously

# For a registration : let's select all slices
mp.selectSlice(mp.getSlices()) # select all

# %%
# Let's run an affine registration on the green slice channel and on the reference atlas channel
# elastix needs to be setup, see https://biop.github.io/ijp-imagetoatlas/installation.html
RegistrationElastixAffineCommand = jimport('ch.epfl.biop.atlas.aligner.command.RegistrationElastixAffineCommand')

ij.command().run(RegistrationElastixAffineCommand, True,
                 "mp", mp,\
                 "pixel_size_micrometer", 40,\
                 "show_imageplus_registration_result", False,\
                 "background_offset_value_moving",0,\
                 "atlas_image_channel",0,\
                 "slice_image_channel",1) # second channel, 0-based

# %%
# Let's try spline
RegistrationElastixSplineCommand = jimport('ch.epfl.biop.atlas.aligner.command.RegistrationElastixSplineCommand')

ij.command().run(RegistrationElastixSplineCommand, True,
                 "mp", mp,\
                 "nb_control_points_x", 12,\
                 "pixel_size_micrometer", 20,\
                 "show_imageplus_registration_result", False,\
                 "background_offset_value_moving",0,\
                 "atlas_image_channel",0,\
                 "slice_image_channel",1) # second channel, 0-based

# %%
# Let's wait for all registration to finish
mp.waitForTasks()
